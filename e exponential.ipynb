# %%
from sympy import *
x,y,z=symbols('x y z')
init_printing()
# %matplotlib notebook

# %% [markdown]
# ## e

# %% [markdown]
# Defined as:
#
# $$e=\lim_{n \rightarrow \infty}(1+\frac{1}{n})^n$$

# %%
E.n()
# Out:
# 2.71828182845905

# %%
plot(E**x)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# e is it's own differential

# %%
diff(E**x,x)
# Out:
#  x
# ℯ

# %% [markdown]
# ## Compound interest

# %% [markdown]
# $$A = P \left(1+\frac{r}{n}\right) ^{nt}$$
#
# and
#
# $$\lim_{n \rightarrow \infty}P \left(1+\frac{r}{n}\right) ^{nt}=Pe^{rt}$$

# %% [markdown]
# ## Radioactive decay

# %%
Q_0,r,t = symbols('Q_0 r t',real=true)
Qt = Q_0*E**(r*t)
Qt
# Out:
#     r⋅t
# Q₀⋅ℯ

# %% [markdown]
# ### Half life

# %%
eq1=Eq(Qt.subs([(r,-0.0001238),(Q_0,1.0)]),0.5)
eq1
# Out:
#      -0.0001238⋅t
# 1.0⋅ℯ             = 0.5

# %%
solve(eq1,t)
# Out:
# [5598.92714507226]

# %% [markdown]
# ### Population model
#
# Current population growth rate is 1.3% per year.
#
# Time to double population

# %%
eq2=Eq(2.0,Qt.subs([(Q_0,1.0),(r,0.013)]))
eq2
# Out:
#            0.013⋅t
# 2.0 = 1.0⋅ℯ

# %%
solve(eq2,t)[0].n(2)
# Out:
# 53.
